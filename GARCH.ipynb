# %%
import pandas as pd
import numpy as np
import arch
from arch import arch_model
import os

import matplotlib.pyplot as plt

data_folder = 'data'
stock_files = [os.path.join(data_folder, file) for file in os.listdir(data_folder) if file.endswith('.csv')]
for stock in stock_files:
    stock_data = pd.read_csv(stock)
    stock_data['Date'] = pd.to_datetime(stock_data['Date'], format='%d/%m/%Y')
    stock_data.set_index('Date', inplace=True)
    stock_data['LogReturn'] = np.log(stock_data['Close'] / stock_data['Close'].shift(1))
    
    
    stock_data['LogReturn'] = stock_data['LogReturn'].replace([np.inf, -np.inf], np.nan)
    stock_data.dropna(subset=['LogReturn'], inplace=True)
    
    # Rescaling the 'LogReturn' to improve model parameter estimation
    stock_data['LogReturn'] = stock_data['LogReturn'] * 100
    
    garch_model = arch_model(stock_data['LogReturn'], vol='Garch', p=1, q=1)
    garch_result = garch_model.fit()
    print(garch_result.summary())
    
    time_periods = {
        '3M': '3M',
        '6M': '6M',
        '9M': '9M',
        'Full Period': None
    }
    
    for period, freq in time_periods.items():
        if freq:
    
            period_data = stock_data.loc[stock_data.index >= (stock_data.index.max() - pd.DateOffset(months=3*int(freq[0])))]
        else:
            period_data = stock_data
        
        period_log_return = period_data['LogReturn'].dropna()
        period_garch_model = arch_model(period_log_return, vol='Garch', p=1, q=1)
        period_garch_result = period_garch_model.fit(disp='off')
        
        conditional_volatility = period_garch_result.conditional_volatility
        
        mean_volatility = conditional_volatility.mean()
        
        annualized_volatility = mean_volatility * np.sqrt(252)  # Assuming 252 trading days in a year
        
        print(f"Stock: {stock[:-4]} - Volatility for {period}: {mean_volatility:.4f}")
        print(f"Stock: {stock[:-4]} - Annualized Volatility for {period}: {annualized_volatility:.4f}")


        plt.figure(figsize=(10, 6))
        plt.plot(stock_data.index, garch_result.conditional_volatility, label='Conditional Volatility')
        plt.title(f'GARCH Model Conditional Volatility for {os.path.basename(stock)[:-4]} - {period}')
        plt.xlabel('Date')
        plt.ylabel('Volatility')
        plt.legend()
        plt.show()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 6701.17152103244
# Iteration:      2,   Func. Count:     15,   Neg. LLF: 3131.9279864705954
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 2212.1004251996815
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 2185.4864142972456
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 2159.564920516951
# Iteration:      6,   Func. Count:     41,   Neg. LLF: 2159.447392796237
# Iteration:      7,   Func. Count:     46,   Neg. LLF: 2159.447355714792
# Iteration:      8,   Func. Count:     51,   Neg. LLF: 2159.4473540166737
# Iteration:      9,   Func. Count:     55,   Neg. LLF: 2159.447354016761
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2159.4473540166737
#             Iterations: 9
#             Function evaluations: 55
#             Gradient evaluations: 9
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:              LogReturn   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2159.45
# Distribution:                  Normal   AIC:                           4326.89
# Method:            Maximum Likelihood   BIC:                           4347.33
#                                         No. Observations:                 1223
# Date:                Thu, Nov 28 2024   Df Residuals:                     1222
# Time:                        16:50:24   Df Model:                            1
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# mu             0.0432  3.923e-02      1.101      0.271 [-3.369e-02,  0.120]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0

#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          1.7783      0.252      7.069  1.565e-12    [  1.285,  2.271]
# alpha[1]       0.2097  9.184e-02      2.283  2.243e-02  [2.966e-02,  0.390]
# beta[1]    4.0526e-03  5.226e-02  7.754e-02      0.938 [-9.838e-02,  0.106]
# ===========================================================================
#
# Covariance estimator: robust
# Stock: data/bajaj - Volatility for 3M: 1.4488
# Stock: data/bajaj - Annualized Volatility for 3M: 22.9992
# Stock: data/bajaj - Volatility for 6M: 1.5423
# Stock: data/bajaj - Annualized Volatility for 6M: 24.4829
# Stock: data/bajaj - Volatility for 9M: 1.4769
# Stock: data/bajaj - Annualized Volatility for 9M: 23.4446
# Stock: data/bajaj - Volatility for Full Period: 1.4782
# Stock: data/bajaj - Annualized Volatility for Full Period: 23.4659
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 6802.476548920609
# Iteration:      2,   Func. Count:     15,   Neg. LLF: 79386.41513130753
# Iteration:      3,   Func. Count:     23,   Neg. LLF: 2257.3634713857195
# Iteration:      4,   Func. Count:     30,   Neg. LLF: 5942931.436216007
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 2235.380717440677
# Iteration:      6,   Func. Count:     42,   Neg. LLF: 2288.1668847106457
# Iteration:      7,   Func. Count:     48,   Neg. LLF: 2232.6316077731763
# Iteration:      8,   Func. Count:     54,   Neg. LLF: 2214.312425975293
# Iteration:      9,   Func. Count:     60,   Neg. LLF: 2213.970194198998
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 2213.968477805697
# Iteration:     11,   Func. Count:     70,   Neg. LLF: 2213.9684622554705
# Iteration:     12,   Func. Count:     76,   Neg. LLF: 2213.968283016142
# Iteration:     13,   Func. Count:     81,   Neg. LLF: 2213.9682826871913
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2213.9682826871913
#             Iterations: 13
#             Function evaluations: 81
#             Gradient evaluations: 13
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:              LogReturn   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2213.97
# Distribution:                  Normal   AIC:                           4435.94
# Method:            Maximum Likelihood   BIC:                           4456.37
#                                         No. Observations:                 1223
# Date:                Thu, Nov 28 2024   Df Residuals:                     1222
# Time:                        16:50:27   Df Model:                            1
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.0869  3.934e-02      2.209  2.715e-02 [9.811e-03,  0.164]
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          0.1439      0.113      1.277      0.202 [-7.693e-02,  0.365]
# alpha[1]       0.0596  3.540e-02      1.683  9.237e-02 [-9.803e-03,  0.129]
# beta[1]        0.8757  7.922e-02     11.054  2.104e-28    [  0.720,  1.031]
# ===========================================================================
#
# Covariance estimator: robust
# Stock: data/asianpaints - Volatility for 3M: 1.4228
# Stock: data/asianpaints - Annualized Volatility for 3M: 22.5867
# Stock: data/asianpaints - Volatility for 6M: 1.4446
# Stock: data/asianpaints - Annualized Volatility for 6M: 22.9317
# Stock: data/asianpaints - Volatility for 9M: 1.3748
# Stock: data/asianpaints - Annualized Volatility for 9M: 21.8237
# Stock: data/asianpaints - Volatility for Full Period: 1.4933
# Stock: data/asianpaints - Annualized Volatility for Full Period: 23.7060
